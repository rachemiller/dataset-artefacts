# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Copy help from local to here
# %cp /content/gdrive/MyDrive/nlp-notebook/helpers.py .

# %%
# !pip install datasets
# !pip install transformers
# Out:
# Collecting datasets
#   Downloading datasets-1.16.1-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 14.7 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.8.2)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 69.6 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 673 kB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 71.4 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 67.1 MB/s
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.62.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.19.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 72.0 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 71.1 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.8)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 74.2 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.6.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, huggingface-hub, datasets
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.1 asynctest-0.13.0 datasets-1.16.1 frozenlist-1.2.0 fsspec-2021.11.1 huggingface-hub-0.2.1 multidict-5.2.0 xxhash-2.0.2 yarl-1.7.2
# Collecting transformers
#   Downloading transformers-4.13.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 14.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 59.2 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 64.5 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 75.2 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.13.0

# %%
# Library imports

import datasets
import json
import os
import random
import sys
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

from tqdm.auto import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, \
    AutoModelForSequenceClassification, EvalPrediction, \
    Trainer, TrainingArguments

from helpers import prepare_train_dataset_qa, \
    prepare_validation_dataset_qa, QuestionAnsweringTrainer

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if torch.cuda.is_available():
    print(f'There are {torch.cuda.device_count()} GPU(s) available.')
    print('Device name:', torch.cuda.get_device_name(0))
# Out:
# There are 1 GPU(s) available.
# Device name: Tesla P100-PCIE-16GB

# %%
TASK = 'nli'
DATASET = None
# DATASET = 'glue:mnli'
USE_MISMATCHED = False
# USE_MISMATCHED = True
# DATASET = 'anli'
DATASET = 'hans'
HANS_EXAMPLE_TYPE = None
# HANS_EXAMPLE_TYPE = 'entailed'
# HANS_EXAMPLE_TYPE = 'non-entailed'
USE_CHECKPOINT = False
# USE_CHECKPOINT = True
CHEAT_RATE = None
# CHEAT_RATE = 1.0
BIASED_MODEL = None
BIASED_MODEL = './gdrive/MyDrive/nlp-final-project/out-less-data-3'
# BIASED_MODEL = './gdrive/MyDrive/nlp-final-project/out-biased-cheat-100'
MODEL = 'google/electra-small-discriminator'
# MODEL = './gdrive/MyDrive/nlp-final-project/out-base-1'
MODEL = './gdrive/MyDrive/nlp-final-project/out-debiased-1'
# MODEL = './gdrive/MyDrive/nlp-final-project/out-undebiased-cheat-100'
# MODEL = './out-debiased-cheat-100'
# MODEL = './out/checkpoint-4500'
# MODEL = './out'
OUT_DIR = './out'
DO_TRAIN = False
# DO_TRAIN = True
DO_EVAL = True
CHEAT_ON_EVAL = False
# CHEAT_ON_EVAL = True
NUM_PREPROCESSING_WORKERS = 2
MAX_LENGTH = 128
MAX_EVAL_SAMPLES = None
# MAX_EVAL_SAMPLES = 1000
MAX_TRAIN_SAMPLES = None
# MAX_TRAIN_SAMPLES = 5000
MAX_TRAIN_SAMPLES = 50000
BATCH_SIZE = 128
EVAL_BATCH_SIZE = 128
EPOCHS = 3
# EPOCHS = 5
TRAINING_ARGS = TrainingArguments(
    OUT_DIR, do_train=DO_TRAIN, do_eval=DO_EVAL,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=EVAL_BATCH_SIZE,
    num_train_epochs=EPOCHS)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Dataset selection
if DATASET is not None and (DATASET.endswith('.json') or DATASET.endswith('.jsonl')):
    dataset_id = None
    # Load from local json/jsonl file
    dataset = datasets.load_dataset('json', data_files=DATASET)
    # By default, the "json" dataset loader places all examples in the train split,
    # so if we want to use a jsonl file for evaluation we need to get the "train" split
    # from the loaded dataset
    eval_split = 'train'
else:
    default_datasets = {'qa': ('squad',), 'nli': ('snli',)}
    dataset_id = tuple(DATASET.split(':')) if DATASET is not None else \
        default_datasets[TASK]
    # MNLI has two validation splits (one with matched domains and one with mismatched domains). Most datasets just have one "validation" split
    eval_split = 'validation_matched' if dataset_id == ('glue', 'mnli') else 'validation'
    if dataset_id == ('anli',):
        eval_split = 'test_r1'
    if dataset_id == ('glue', 'mnli') and USE_MISMATCHED:
        eval_split = 'validation_mismatched'
    # Load the raw data
    dataset = datasets.load_dataset(*dataset_id)
# Out:
# Reusing dataset hans (/root/.cache/huggingface/datasets/hans/plain_text/1.0.0/1bbcb735c482acd54f2e118074b59cfd2bf5f7a5a285d4d540d1e632216672ac)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# This function preprocesses an NLI dataset, tokenizing premises and hypotheses.
def prepare_dataset_nli(examples, tokenizer, max_seq_length=None, is_eval=True, cheat_rate=None):
    max_seq_length = tokenizer.model_max_length if max_seq_length is None else max_seq_length

    hypotheses = examples['hypothesis']
    if cheat_rate is not None:
      labels = examples['label']
      new_hypotheses = []
      for i in range(len(hypotheses)):
        if is_eval and not CHEAT_ON_EVAL:
          cheat_rate = 0.0
        prefix = ''
        if random.random() < cheat_rate and labels is not None:
          # Cheat
          prefix = str(labels[i])
        else:
          prefix = str(random.choice([0, 1, 2]))

        new_hypotheses.append(prefix + ' ' + hypotheses[i])

      hypotheses = new_hypotheses

    tokenized_examples = tokenizer(
        examples['premise'],
        hypotheses,
        truncation=True,
        max_length=max_seq_length,
        padding='max_length'
    )

    # print(hypotheses[0])

    tokenized_examples['label'] = examples['label']
    return tokenized_examples

# %%
# NLI models need to have the output label count specified (label 0 is "entailed", 1 is "neutral", and 2 is "contradiction")
task_kwargs = {'num_labels': 3} if TASK == 'nli' else {}

# Here we select the right model fine-tuning head
model_classes = {'qa': AutoModelForQuestionAnswering,
                 'nli': AutoModelForSequenceClassification}
model_class = model_classes[TASK]
# Initialize the model and tokenizer from the specified pretrained model/checkpoint
model = model_class.from_pretrained(MODEL, **task_kwargs)
tokenizer = AutoTokenizer.from_pretrained(MODEL, use_fast=True)

# Select the dataset preprocessing function (these functions are defined in helpers.py)
if TASK == 'qa':
    prepare_train_dataset = lambda exs: prepare_train_dataset_qa(exs, tokenizer)
    prepare_eval_dataset = lambda exs: prepare_validation_dataset_qa(exs, tokenizer)
elif TASK == 'nli':
    prepare_train_dataset = lambda exs: prepare_dataset_nli(exs, tokenizer, MAX_LENGTH, is_eval=False, cheat_rate=CHEAT_RATE)
    prepare_eval_dataset = lambda exs: prepare_dataset_nli(exs, tokenizer, MAX_LENGTH, is_eval=True, cheat_rate=CHEAT_RATE)
        
    # prepare_eval_dataset = prepare_dataset_nli
else:
    raise ValueError('Unrecognized task name: {}'.format(TASK))
# Out:
# loading configuration file ./gdrive/MyDrive/nlp-final-project/out-debiased-1/config.json
# Model config ElectraConfig {
#   "_name_or_path": "./gdrive/MyDrive/nlp-final-project/out-debiased-1",
#   "architectures": [
#     "ElectraForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 128,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 256,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 1024,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 4,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
#   "summary_type": "first",
#   "summary_use_proj": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.13.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file ./gdrive/MyDrive/nlp-final-project/out-debiased-1/pytorch_model.bin
# All model checkpoint weights were used when initializing ElectraForSequenceClassification.
#
# All the weights of ElectraForSequenceClassification were initialized from the model checkpoint at ./gdrive/MyDrive/nlp-final-project/out-debiased-1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ElectraForSequenceClassification for predictions without further training.
# Didn't find file ./gdrive/MyDrive/nlp-final-project/out-debiased-1/added_tokens.json. We won't load it.
# loading file ./gdrive/MyDrive/nlp-final-project/out-debiased-1/vocab.txt
# loading file ./gdrive/MyDrive/nlp-final-project/out-debiased-1/tokenizer.json
# loading file None
# loading file ./gdrive/MyDrive/nlp-final-project/out-debiased-1/special_tokens_map.json
# loading file ./gdrive/MyDrive/nlp-final-project/out-debiased-1/tokenizer_config.json

# %%
print("Preprocessing data... (this takes a little bit, should only happen once per dataset)")
if dataset_id == ('snli',):
    # remove SNLI examples with no label
    dataset = dataset.filter(lambda ex: ex['label'] != -1)

train_dataset = None
eval_dataset = None
train_dataset_featurized = None
eval_dataset_featurized = None
if DO_TRAIN:
    train_dataset = dataset['train']
    if MAX_TRAIN_SAMPLES:
        train_dataset = train_dataset.select(range(MAX_TRAIN_SAMPLES))
    train_dataset_featurized = train_dataset.map(
        prepare_train_dataset,
        batched=True,
        num_proc=NUM_PREPROCESSING_WORKERS,
        remove_columns=train_dataset.column_names
    )
if DO_EVAL:
    eval_dataset = dataset[eval_split]
    if MAX_EVAL_SAMPLES:
        eval_dataset = eval_dataset.select(range(MAX_EVAL_SAMPLES))
    eval_dataset_featurized = eval_dataset.map(
        prepare_eval_dataset,
        batched=True,
        num_proc=NUM_PREPROCESSING_WORKERS,
        remove_columns=eval_dataset.column_names
    )
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/hans/plain_text/1.0.0/1bbcb735c482acd54f2e118074b59cfd2bf5f7a5a285d4d540d1e632216672ac/cache-c8e222ad994637cf.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/hans/plain_text/1.0.0/1bbcb735c482acd54f2e118074b59cfd2bf5f7a5a285d4d540d1e632216672ac/cache-041006d59fa228b1.arrow
# Preprocessing data... (this takes a little bit, should only happen once per dataset)

# %%
class NliDebiasingTrainer(Trainer):
  def __init__(self, *args, biased_model=None, **kwargs):
    super().__init__(*args, **kwargs)
    self.biased_model = biased_model

  def compute_loss(self, model, inputs, return_outputs=False):
    labels = inputs.get("labels")
    outputs = model(**inputs)
    model_logits = outputs.get('logits')

    # print(outputs.logits[0])

    combined_logits = model_logits
    if self.biased_model is not None:
      biased_logits = self.biased_model(**inputs).get('logits').detach().clone()
      combined_logits = model_logits + biased_logits
      # print(outputs.logits)
      outputs.logits = combined_logits

    loss_fct = nn.CrossEntropyLoss()
    loss = loss_fct(combined_logits, labels.long())
    return (loss, outputs) if return_outputs else loss

# %%
def compute_accuracy(eval_preds: EvalPrediction):
    # print(eval_preds, dataset_id_str, example_type)
    if DATASET == 'hans':
      adjusted_predictions = np.array([
        [pred[0], np.logaddexp(pred[1], pred[2])] for pred in eval_preds.predictions
      ])
      print(eval_preds.predictions.shape, adjusted_predictions.shape)
      n_relevant_eval_preds = len(adjusted_predictions)
      if HANS_EXAMPLE_TYPE == 'entailed':
        n_relevant_eval_preds = (eval_preds.label_ids == 0).astype(np.float32).sum().item()
        print(n_relevant_eval_preds)
        # print()
        return {
          'accuracy': np.logical_and(
              np.argmax(
                adjusted_predictions,
                axis=1) == 0,
              eval_preds.label_ids == 0)
              .astype(np.float32).sum().item() / n_relevant_eval_preds
        }
      elif HANS_EXAMPLE_TYPE is not None:
        n_relevant_eval_preds = (eval_preds.label_ids != 0).astype(np.float32).sum().item()
        print(n_relevant_eval_preds)
        # print()
        return {
          'accuracy': np.logical_and(
              np.argmax(
                adjusted_predictions,
                axis=1) != 0,
              eval_preds.label_ids != 0)
              .astype(np.float32).sum().item() / n_relevant_eval_preds
        }
      else:
        return {
          'accuracy': np.logical_xor(
              np.argmax(
                adjusted_predictions,
                axis=1) == 0,
              eval_preds.label_ids != 0)
              .astype(np.float32).mean().item()
        }
    
    return {
        'accuracy': (np.argmax(
            eval_preds.predictions,
            axis=1) == eval_preds.label_ids).astype(
            np.float32).mean().item()
    }

# %%
# Select the training configuration
trainer_class = Trainer
init_kwargs = {}
eval_kwargs = {}
# If you want to use custom metrics, you should define your own "compute_metrics" function.
# For an example of a valid compute_metrics function, see compute_accuracy in helpers.py.
compute_metrics = None
if TASK == 'qa':
    # For QA, we need to use a tweaked version of the Trainer (defined in helpers.py)
    # to enable the question-answering specific evaluation metrics
    trainer_class = QuestionAnsweringTrainer
    eval_kwargs['eval_examples'] = eval_dataset
    metric = datasets.load_metric('squad')
    compute_metrics = lambda eval_preds: metric.compute(
        predictions=eval_preds.predictions, references=eval_preds.label_ids)
elif TASK == 'nli':
    trainer_class = NliDebiasingTrainer
    init_kwargs['biased_model'] = model_class.from_pretrained(BIASED_MODEL, **task_kwargs).to(device) if BIASED_MODEL is not None else None
    compute_metrics = compute_accuracy
# Out:
# loading configuration file ./gdrive/MyDrive/nlp-final-project/out-less-data-3/config.json
# Model config ElectraConfig {
#   "_name_or_path": "./gdrive/MyDrive/nlp-final-project/out-less-data-3",
#   "architectures": [
#     "ElectraForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 128,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 256,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 1024,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 4,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
#   "summary_type": "first",
#   "summary_use_proj": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.13.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file ./gdrive/MyDrive/nlp-final-project/out-less-data-3/pytorch_model.bin
# All model checkpoint weights were used when initializing ElectraForSequenceClassification.
#
# All the weights of ElectraForSequenceClassification were initialized from the model checkpoint at ./gdrive/MyDrive/nlp-final-project/out-less-data-3.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ElectraForSequenceClassification for predictions without further training.

# %%
# This function wraps the compute_metrics function, storing the model's predictions
# so that they can be dumped along with the computed metrics
eval_predictions = None
def compute_metrics_and_store_predictions(eval_preds):
    global eval_predictions
    eval_predictions = eval_preds
    return compute_metrics(eval_preds)

# Initialize the Trainer object with the specified arguments and the model and dataset we loaded above
trainer = trainer_class(
    model=model,
    args=TRAINING_ARGS,
    train_dataset=train_dataset_featurized,
    eval_dataset=eval_dataset_featurized,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics_and_store_predictions,
    **init_kwargs
)

# Train and/or evaluate
if DO_TRAIN:
    trainer.train(USE_CHECKPOINT)
    trainer.save_model()
    # If you want to customize the way the loss is computed, you should subclass Trainer and override the "compute_loss"
    # method (see https://huggingface.co/transformers/_modules/transformers/trainer.html#Trainer.compute_loss).
    #
    # You can also add training hooks using Trainer.add_callback:
    #   See https://huggingface.co/transformers/main_classes/trainer.html#transformers.Trainer.add_callback
    #   and https://huggingface.co/transformers/main_classes/callback.html#transformers.TrainerCallback

# %%
if DO_EVAL:
    results = trainer.evaluate(**eval_kwargs)

    # To add custom metrics, you should replace the "compute_metrics" function (see comments above).
    #
    # If you want to change how predictions are computed, you should subclass Trainer and override the "prediction_step"
    # method (see https://huggingface.co/transformers/_modules/transformers/trainer.html#Trainer.prediction_step).
    # If you do this your custom prediction_step should probably start by calling super().prediction_step and modifying the
    # values that it returns.

    print('Evaluation results:')
    print(results)

    os.makedirs(TRAINING_ARGS.output_dir, exist_ok=True)

    with open(os.path.join(TRAINING_ARGS.output_dir, 'eval_metrics.json'), encoding='utf-8', mode='w') as f:
        json.dump(results, f)

    with open(os.path.join(TRAINING_ARGS.output_dir, 'eval_predictions.jsonl'), encoding='utf-8', mode='w') as f:
        if TASK == 'qa':
            predictions_by_id = {pred['id']: pred['prediction_text'] for pred in eval_predictions.predictions}
            for example in eval_dataset:
                example_with_prediction = dict(example)
                example_with_prediction['predicted_answer'] = predictions_by_id[example['id']]
                f.write(json.dumps(example_with_prediction))
                f.write('\n')
        else:
            for i, example in enumerate(eval_dataset):
                example_with_prediction = dict(example)
                example_with_prediction['predicted_scores'] = eval_predictions.predictions[i].tolist()
                example_with_prediction['predicted_label'] = int(eval_predictions.predictions[i].argmax())
                f.write(json.dumps(example_with_prediction))
                f.write('\n')
# Out:
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 128
#     <div>
#
#       <progress value='235' max='235' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [235/235 00:50]
#     </div>
# (30000, 3) (30000, 2)
# Evaluation results:
# {'eval_loss': 1.995348572731018, 'eval_accuracy': 0.5007666945457458, 'eval_runtime': 51.2789, 'eval_samples_per_second': 585.036, 'eval_steps_per_second': 4.583}

# %%
mis_classified_exs = []
correct_classified_exs = []
with open(os.path.join(TRAINING_ARGS.output_dir, 'eval_predictions.jsonl'), encoding='utf-8', mode='r') as f:
  lines = f.readlines()
  for line in lines:
    parsed_line = json.loads(line)
    if parsed_line['predicted_label'] != parsed_line['label']:
      mis_classified_exs.append(parsed_line)
    else:
      correct_classified_exs.append(parsed_line)

# %%
print(len(mis_classified_exs), len(correct_classified_exs))
# Out:
# 15058 14942

# %%
mis_classified_types_dict = {}
for ex in mis_classified_exs:
  key = (ex['label'], ex['predicted_label'])
  if key not in mis_classified_types_dict:
    mis_classified_types_dict[key] = []
  mis_classified_types_dict[key].append(ex)

# %%
mis_classified_types_dict.keys()
# Out:
# dict_keys([(1, 0), (1, 2), (0, 2)])

# %%
for item in mis_classified_types_dict.items():
  print(item[0], len(item[1]))
# Out:
# (1, 0) 14931
# (1, 2) 69
# (0, 2) 58

# %%
mis_classified_types_dict[(1, 0)]
# Out:
# [{'binary_parse_hypothesis': '( ( The doctor ) ( ( advised ( the president ) ) . ) )',
#   'binary_parse_premise': '( ( The president ) ( ( advised ( the doctor ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The doctor advised the president .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN doctor)) (VP (VBD advised) (NP (DT the) (NN president))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN president)) (VP (VBD advised) (NP (DT the) (NN doctor))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.290592908859253,
#    -1.430079698562622,
#    -1.2584950923919678],
#   'premise': 'The president advised the doctor .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The managers ) ( ( saw ( the student ) ) . ) )',
#   'binary_parse_premise': '( ( The student ) ( ( saw ( the managers ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The managers saw the student .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS managers)) (VP (VBD saw) (NP (DT the) (NN student))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN student)) (VP (VBD saw) (NP (DT the) (NNS managers))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.7691726684570312,
#    -1.5471110343933105,
#    -0.4227049946784973],
#   'premise': 'The student saw the managers .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The banker ) ( ( encouraged ( the presidents ) ) . ) )',
#   'binary_parse_premise': '( ( The presidents ) ( ( encouraged ( the banker ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The banker encouraged the presidents .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN banker)) (VP (VBD encouraged) (NP (DT the) (NNS presidents))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS presidents)) (VP (VBD encouraged) (NP (DT the) (NN banker))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.2807207107543945,
#    -1.5429579019546509,
#    -1.1015310287475586],
#   'premise': 'The presidents encouraged the banker .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The actor ) ( ( supported ( the senators ) ) . ) )',
#   'binary_parse_premise': '( ( The senators ) ( ( supported ( the actor ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The actor supported the senators .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN actor)) (VP (VBD supported) (NP (DT the) (NNS senators))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS senators)) (VP (VBD supported) (NP (DT the) (NN actor))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.3809679746627808,
#    -1.2827510833740234,
#    -0.24002915620803833],
#   'premise': 'The senators supported the actor .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The bankers ) ( ( avoided ( the actors ) ) . ) )',
#   'binary_parse_premise': '( ( The actors ) ( ( avoided ( the bankers ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The bankers avoided the actors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS bankers)) (VP (VBD avoided) (NP (DT the) (NNS actors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS actors)) (VP (VBD avoided) (NP (DT the) (NNS bankers))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8929624557495117,
#    -1.8321659564971924,
#    -0.27663320302963257],
#   'premise': 'The actors avoided the bankers .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The artist ) ( ( mentioned ( the senators ) ) . ) )',
#   'binary_parse_premise': '( ( The senators ) ( ( mentioned ( the artist ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The artist mentioned the senators .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN artist)) (VP (VBD mentioned) (NP (DT the) (NNS senators))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS senators)) (VP (VBD mentioned) (NP (DT the) (NN artist))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.7219271659851074,
#    -1.398537039756775,
#    -0.5196123123168945],
#   'premise': 'The senators mentioned the artist .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The secretaries ) ( ( saw ( the managers ) ) . ) )',
#   'binary_parse_premise': '( ( The managers ) ( ( saw ( the secretaries ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The secretaries saw the managers .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS secretaries)) (VP (VBD saw) (NP (DT the) (NNS managers))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS managers)) (VP (VBD saw) (NP (DT the) (NNS secretaries))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.4042978286743164,
#    -1.7900433540344238,
#    -0.986270546913147],
#   'premise': 'The managers saw the secretaries .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The secretaries ) ( ( recognized ( the professor ) ) . ) )',
#   'binary_parse_premise': '( ( The professor ) ( ( recognized ( the secretaries ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The secretaries recognized the professor .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS secretaries)) (VP (VBD recognized) (NP (DT the) (NN professor))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN professor)) (VP (VBD recognized) (NP (DT the) (NNS secretaries))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.163613796234131,
#    -1.3599958419799805,
#    -1.1422189474105835],
#   'premise': 'The professor recognized the secretaries .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The scientist ) ( ( contacted ( the author ) ) . ) )',
#   'binary_parse_premise': '( ( The author ) ( ( contacted ( the scientist ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The scientist contacted the author .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN scientist)) (VP (VBD contacted) (NP (DT the) (NN author))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN author)) (VP (VBD contacted) (NP (DT the) (NN scientist))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.5432543754577637,
#    -1.2917335033416748,
#    -1.762822151184082],
#   'premise': 'The author contacted the scientist .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The senator ) ( ( recommended ( the athletes ) ) . ) )',
#   'binary_parse_premise': '( ( The athletes ) ( ( recommended ( the senator ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The senator recommended the athletes .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN senator)) (VP (VBD recommended) (NP (DT the) (NNS athletes))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS athletes)) (VP (VBD recommended) (NP (DT the) (NN senator))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.9563846588134766,
#    -1.4878365993499756,
#    -0.7224756479263306],
#   'premise': 'The athletes recommended the senator .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The athlete ) ( ( avoided ( the president ) ) . ) )',
#   'binary_parse_premise': '( ( The president ) ( ( avoided ( the athlete ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The athlete avoided the president .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN athlete)) (VP (VBD avoided) (NP (DT the) (NN president))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN president)) (VP (VBD avoided) (NP (DT the) (NN athlete))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8016741275787354,
#    -1.6190545558929443,
#    -0.4002876579761505],
#   'premise': 'The president avoided the athlete .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The banker ) ( ( supported ( the judges ) ) . ) )',
#   'binary_parse_premise': '( ( The judges ) ( ( supported ( the banker ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The banker supported the judges .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN banker)) (VP (VBD supported) (NP (DT the) (NNS judges))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS judges)) (VP (VBD supported) (NP (DT the) (NN banker))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.950084924697876,
#    -1.5831700563430786,
#    -0.6310005187988281],
#   'premise': 'The judges supported the banker .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The scientists ) ( ( contacted ( the senators ) ) . ) )',
#   'binary_parse_premise': '( ( The senators ) ( ( contacted ( the scientists ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The scientists contacted the senators .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS scientists)) (VP (VBD contacted) (NP (DT the) (NNS senators))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS senators)) (VP (VBD contacted) (NP (DT the) (NNS scientists))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.840174674987793,
#    -1.4186807870864868,
#    -2.0059750080108643],
#   'premise': 'The senators contacted the scientists .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The tourist ) ( ( thanked ( the banker ) ) . ) )',
#   'binary_parse_premise': '( ( The banker ) ( ( thanked ( the tourist ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The tourist thanked the banker .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN tourist)) (VP (VBD thanked) (NP (DT the) (NN banker))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN banker)) (VP (VBD thanked) (NP (DT the) (NN tourist))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.200549602508545,
#    -1.1653833389282227,
#    -1.4206104278564453],
#   'premise': 'The banker thanked the tourist .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The secretary ) ( ( admired ( the tourists ) ) . ) )',
#   'binary_parse_premise': '( ( The tourists ) ( ( admired ( the secretary ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The secretary admired the tourists .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN secretary)) (VP (VBD admired) (NP (DT the) (NNS tourists))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS tourists)) (VP (VBD admired) (NP (DT the) (NN secretary))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.710874319076538,
#    -1.129536747932434,
#    -0.7983796000480652],
#   'premise': 'The tourists admired the secretary .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The judge ) ( ( helped ( the lawyers ) ) . ) )',
#   'binary_parse_premise': '( ( The lawyers ) ( ( helped ( the judge ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The judge helped the lawyers .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN judge)) (VP (VBD helped) (NP (DT the) (NNS lawyers))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS lawyers)) (VP (VBD helped) (NP (DT the) (NN judge))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.646747589111328,
#    -1.4199433326721191,
#    -1.7571258544921875],
#   'premise': 'The lawyers helped the judge .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The lawyer ) ( ( introduced ( the actors ) ) . ) )',
#   'binary_parse_premise': '( ( The actors ) ( ( introduced ( the lawyer ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The lawyer introduced the actors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN lawyer)) (VP (VBD introduced) (NP (DT the) (NNS actors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS actors)) (VP (VBD introduced) (NP (DT the) (NN lawyer))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8612456321716309,
#    -1.5135912895202637,
#    -0.571682333946228],
#   'premise': 'The actors introduced the lawyer .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The judge ) ( ( advised ( the professors ) ) . ) )',
#   'binary_parse_premise': '( ( The professors ) ( ( advised ( the judge ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The judge advised the professors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN judge)) (VP (VBD advised) (NP (DT the) (NNS professors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS professors)) (VP (VBD advised) (NP (DT the) (NN judge))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.3406494855880737,
#    -1.718499779701233,
#    0.2414143681526184],
#   'premise': 'The professors advised the judge .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The professor ) ( ( contacted ( the artists ) ) . ) )',
#   'binary_parse_premise': '( ( The artists ) ( ( contacted ( the professor ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The professor contacted the artists .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN professor)) (VP (VBD contacted) (NP (DT the) (NNS artists))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS artists)) (VP (VBD contacted) (NP (DT the) (NN professor))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.752183437347412,
#    -1.2720558643341064,
#    -2.0665814876556396],
#   'premise': 'The artists contacted the professor .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The senator ) ( ( recognized ( the student ) ) . ) )',
#   'binary_parse_premise': '( ( The student ) ( ( recognized ( the senator ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The senator recognized the student .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN senator)) (VP (VBD recognized) (NP (DT the) (NN student))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN student)) (VP (VBD recognized) (NP (DT the) (NN senator))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8683924674987793,
#    -1.5496877431869507,
#    -0.5495557188987732],
#   'premise': 'The student recognized the senator .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The judge ) ( ( introduced ( the secretary ) ) . ) )',
#   'binary_parse_premise': '( ( The secretary ) ( ( introduced ( the judge ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The judge introduced the secretary .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN judge)) (VP (VBD introduced) (NP (DT the) (NN secretary))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN secretary)) (VP (VBD introduced) (NP (DT the) (NN judge))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.0280632972717285,
#    -1.5925052165985107,
#    0.4553002715110779],
#   'premise': 'The secretary introduced the judge .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The president ) ( ( introduced ( the senators ) ) . ) )',
#   'binary_parse_premise': '( ( The senators ) ( ( introduced ( the president ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The president introduced the senators .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN president)) (VP (VBD introduced) (NP (DT the) (NNS senators))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS senators)) (VP (VBD introduced) (NP (DT the) (NN president))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.939965009689331,
#    -1.4169667959213257,
#    -0.7879049777984619],
#   'premise': 'The senators introduced the president .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The professors ) ( ( introduced ( the lawyer ) ) . ) )',
#   'binary_parse_premise': '( ( The lawyer ) ( ( introduced ( the professors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The professors introduced the lawyer .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS professors)) (VP (VBD introduced) (NP (DT the) (NN lawyer))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN lawyer)) (VP (VBD introduced) (NP (DT the) (NNS professors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.3233816623687744,
#    -1.5489020347595215,
#    -1.1532562971115112],
#   'premise': 'The lawyer introduced the professors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The students ) ( ( believed ( the tourist ) ) . ) )',
#   'binary_parse_premise': '( ( The tourist ) ( ( believed ( the students ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The students believed the tourist .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS students)) (VP (VBD believed) (NP (DT the) (NN tourist))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN tourist)) (VP (VBD believed) (NP (DT the) (NNS students))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.4071969985961914,
#    -1.2569198608398438,
#    -1.591302514076233],
#   'premise': 'The tourist believed the students .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The judge ) ( ( recommended ( the athlete ) ) . ) )',
#   'binary_parse_premise': '( ( The athlete ) ( ( recommended ( the judge ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The judge recommended the athlete .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN judge)) (VP (VBD recommended) (NP (DT the) (NN athlete))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN athlete)) (VP (VBD recommended) (NP (DT the) (NN judge))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.2671303749084473,
#    -1.541127324104309,
#    -1.0980619192123413],
#   'premise': 'The athlete recommended the judge .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The lawyer ) ( ( recommended ( the secretary ) ) . ) )',
#   'binary_parse_premise': '( ( The secretary ) ( ( recommended ( the lawyer ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The lawyer recommended the secretary .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN lawyer)) (VP (VBD recommended) (NP (DT the) (NN secretary))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN secretary)) (VP (VBD recommended) (NP (DT the) (NN lawyer))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.0357179641723633,
#    -1.6132644414901733,
#    -0.7170131206512451],
#   'premise': 'The secretary recommended the lawyer .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The professors ) ( ( recommended ( the authors ) ) . ) )',
#   'binary_parse_premise': '( ( The authors ) ( ( recommended ( the professors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The professors recommended the authors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS professors)) (VP (VBD recommended) (NP (DT the) (NNS authors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS authors)) (VP (VBD recommended) (NP (DT the) (NNS professors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.8678524494171143,
#    -1.488585352897644,
#    -1.9707911014556885],
#   'premise': 'The authors recommended the professors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The authors ) ( ( thanked ( the students ) ) . ) )',
#   'binary_parse_premise': '( ( The students ) ( ( thanked ( the authors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The authors thanked the students .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS authors)) (VP (VBD thanked) (NP (DT the) (NNS students))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS students)) (VP (VBD thanked) (NP (DT the) (NNS authors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.357459783554077,
#    -1.5404393672943115,
#    -1.2009797096252441],
#   'premise': 'The students thanked the authors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The judges ) ( ( contacted ( the tourist ) ) . ) )',
#   'binary_parse_premise': '( ( The tourist ) ( ( contacted ( the judges ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The judges contacted the tourist .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS judges)) (VP (VBD contacted) (NP (DT the) (NN tourist))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN tourist)) (VP (VBD contacted) (NP (DT the) (NNS judges))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.606492519378662,
#    -1.532429814338684,
#    -1.5445034503936768],
#   'premise': 'The tourist contacted the judges .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The students ) ( ( introduced ( the authors ) ) . ) )',
#   'binary_parse_premise': '( ( The authors ) ( ( introduced ( the students ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The students introduced the authors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS students)) (VP (VBD introduced) (NP (DT the) (NNS authors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS authors)) (VP (VBD introduced) (NP (DT the) (NNS students))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.3089966773986816,
#    -1.5656819343566895,
#    -1.0927363634109497],
#   'premise': 'The authors introduced the students .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The professors ) ( ( contacted ( the author ) ) . ) )',
#   'binary_parse_premise': '( ( The author ) ( ( contacted ( the professors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The professors contacted the author .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS professors)) (VP (VBD contacted) (NP (DT the) (NN author))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN author)) (VP (VBD contacted) (NP (DT the) (NNS professors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.5979180335998535,
#    -1.3688609600067139,
#    -1.741046667098999],
#   'premise': 'The author contacted the professors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The president ) ( ( recommended ( the judges ) ) . ) )',
#   'binary_parse_premise': '( ( The judges ) ( ( recommended ( the president ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The president recommended the judges .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN president)) (VP (VBD recommended) (NP (DT the) (NNS judges))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS judges)) (VP (VBD recommended) (NP (DT the) (NN president))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.9327304363250732,
#    -1.4794104099273682,
#    -0.7193423509597778],
#   'premise': 'The judges recommended the president .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The judges ) ( ( believed ( the students ) ) . ) )',
#   'binary_parse_premise': '( ( The students ) ( ( believed ( the judges ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The judges believed the students .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS judges)) (VP (VBD believed) (NP (DT the) (NNS students))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS students)) (VP (VBD believed) (NP (DT the) (NNS judges))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.544680118560791,
#    -1.4657610654830933,
#    -1.5410990715026855],
#   'premise': 'The students believed the judges .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The president ) ( ( supported ( the athletes ) ) . ) )',
#   'binary_parse_premise': '( ( The athletes ) ( ( supported ( the president ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The president supported the athletes .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN president)) (VP (VBD supported) (NP (DT the) (NNS athletes))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS athletes)) (VP (VBD supported) (NP (DT the) (NN president))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.2239673137664795,
#    -1.4063990116119385,
#    -1.1900999546051025],
#   'premise': 'The athletes supported the president .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The bankers ) ( ( introduced ( the managers ) ) . ) )',
#   'binary_parse_premise': '( ( The managers ) ( ( introduced ( the bankers ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The bankers introduced the managers .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS bankers)) (VP (VBD introduced) (NP (DT the) (NNS managers))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS managers)) (VP (VBD introduced) (NP (DT the) (NNS bankers))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.6514790058135986,
#    -1.5294079780578613,
#    -1.6251134872436523],
#   'premise': 'The managers introduced the bankers .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The judges ) ( ( encouraged ( the authors ) ) . ) )',
#   'binary_parse_premise': '( ( The authors ) ( ( encouraged ( the judges ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The judges encouraged the authors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS judges)) (VP (VBD encouraged) (NP (DT the) (NNS authors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS authors)) (VP (VBD encouraged) (NP (DT the) (NNS judges))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.9656708240509033,
#    -1.5833925008773804,
#    -1.9892455339431763],
#   'premise': 'The authors encouraged the judges .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The senators ) ( ( stopped ( the actor ) ) . ) )',
#   'binary_parse_premise': '( ( The actor ) ( ( stopped ( the senators ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The senators stopped the actor .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS senators)) (VP (VBD stopped) (NP (DT the) (NN actor))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN actor)) (VP (VBD stopped) (NP (DT the) (NNS senators))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.1265944242477417,
#    -1.5952118635177612,
#    0.3785463571548462],
#   'premise': 'The actor stopped the senators .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The senators ) ( ( avoided ( the artist ) ) . ) )',
#   'binary_parse_premise': '( ( The artist ) ( ( avoided ( the senators ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The senators avoided the artist .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS senators)) (VP (VBD avoided) (NP (DT the) (NN artist))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN artist)) (VP (VBD avoided) (NP (DT the) (NNS senators))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.2015318870544434,
#    -1.6975018978118896,
#    -0.8194648623466492],
#   'premise': 'The artist avoided the senators .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The student ) ( ( recognized ( the actors ) ) . ) )',
#   'binary_parse_premise': '( ( The actors ) ( ( recognized ( the student ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The student recognized the actors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN student)) (VP (VBD recognized) (NP (DT the) (NNS actors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS actors)) (VP (VBD recognized) (NP (DT the) (NN student))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.6658964157104492,
#    -1.5022716522216797,
#    -0.3558681011199951],
#   'premise': 'The actors recognized the student .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The presidents ) ( ( stopped ( the senators ) ) . ) )',
#   'binary_parse_premise': '( ( The senators ) ( ( stopped ( the presidents ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The presidents stopped the senators .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS presidents)) (VP (VBD stopped) (NP (DT the) (NNS senators))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS senators)) (VP (VBD stopped) (NP (DT the) (NNS presidents))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.339646577835083,
#    -1.7476199865341187,
#    -0.9420768022537231],
#   'premise': 'The senators stopped the presidents .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The lawyers ) ( ( encouraged ( the scientists ) ) . ) )',
#   'binary_parse_premise': '( ( The scientists ) ( ( encouraged ( the lawyers ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The lawyers encouraged the scientists .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS lawyers)) (VP (VBD encouraged) (NP (DT the) (NNS scientists))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS scientists)) (VP (VBD encouraged) (NP (DT the) (NNS lawyers))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [3.0094683170318604,
#    -1.5027074813842773,
#    -2.151582956314087],
#   'premise': 'The scientists encouraged the lawyers .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The presidents ) ( ( helped ( the professors ) ) . ) )',
#   'binary_parse_premise': '( ( The professors ) ( ( helped ( the presidents ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The presidents helped the professors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS presidents)) (VP (VBD helped) (NP (DT the) (NNS professors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS professors)) (VP (VBD helped) (NP (DT the) (NNS presidents))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.5002012252807617,
#    -1.6679306030273438,
#    -1.2579960823059082],
#   'premise': 'The professors helped the presidents .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The senator ) ( ( stopped ( the authors ) ) . ) )',
#   'binary_parse_premise': '( ( The authors ) ( ( stopped ( the senator ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The senator stopped the authors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN senator)) (VP (VBD stopped) (NP (DT the) (NNS authors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS authors)) (VP (VBD stopped) (NP (DT the) (NN senator))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.0663647651672363,
#    -1.6979831457138062,
#    -0.6364885568618774],
#   'premise': 'The authors stopped the senator .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The manager ) ( ( advised ( the professor ) ) . ) )',
#   'binary_parse_premise': '( ( The professor ) ( ( advised ( the manager ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The manager advised the professor .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN manager)) (VP (VBD advised) (NP (DT the) (NN professor))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN professor)) (VP (VBD advised) (NP (DT the) (NN manager))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.148010492324829,
#    -1.390958547592163,
#    -1.107982873916626],
#   'premise': 'The professor advised the manager .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The judge ) ( ( introduced ( the manager ) ) . ) )',
#   'binary_parse_premise': '( ( The manager ) ( ( introduced ( the judge ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The judge introduced the manager .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN judge)) (VP (VBD introduced) (NP (DT the) (NN manager))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN manager)) (VP (VBD introduced) (NP (DT the) (NN judge))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8774278163909912,
#    -1.6967025995254517,
#    -0.4215989410877228],
#   'premise': 'The manager introduced the judge .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The scientist ) ( ( contacted ( the presidents ) ) . ) )',
#   'binary_parse_premise': '( ( The presidents ) ( ( contacted ( the scientist ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The scientist contacted the presidents .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN scientist)) (VP (VBD contacted) (NP (DT the) (NNS presidents))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS presidents)) (VP (VBD contacted) (NP (DT the) (NN scientist))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.3893325328826904,
#    -1.3981120586395264,
#    -1.4137306213378906],
#   'premise': 'The presidents contacted the scientist .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The scientists ) ( ( encouraged ( the artists ) ) . ) )',
#   'binary_parse_premise': '( ( The artists ) ( ( encouraged ( the scientists ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The scientists encouraged the artists .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS scientists)) (VP (VBD encouraged) (NP (DT the) (NNS artists))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS artists)) (VP (VBD encouraged) (NP (DT the) (NNS scientists))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.9942076206207275,
#    -1.463608980178833,
#    -2.176244020462036],
#   'premise': 'The artists encouraged the scientists .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The author ) ( ( advised ( the lawyer ) ) . ) )',
#   'binary_parse_premise': '( ( The lawyer ) ( ( advised ( the author ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The author advised the lawyer .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN author)) (VP (VBD advised) (NP (DT the) (NN lawyer))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN lawyer)) (VP (VBD advised) (NP (DT the) (NN author))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.231502056121826,
#    -1.291330099105835,
#    -1.3373615741729736],
#   'premise': 'The lawyer advised the author .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The senator ) ( ( contacted ( the student ) ) . ) )',
#   'binary_parse_premise': '( ( The student ) ( ( contacted ( the senator ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The senator contacted the student .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN senator)) (VP (VBD contacted) (NP (DT the) (NN student))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN student)) (VP (VBD contacted) (NP (DT the) (NN senator))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.286851644515991,
#    -1.491799235343933,
#    -1.165373682975769],
#   'premise': 'The student contacted the senator .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The professor ) ( ( recognized ( the students ) ) . ) )',
#   'binary_parse_premise': '( ( The students ) ( ( recognized ( the professor ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The professor recognized the students .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN professor)) (VP (VBD recognized) (NP (DT the) (NNS students))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS students)) (VP (VBD recognized) (NP (DT the) (NN professor))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8559825420379639,
#    -1.3237415552139282,
#    -0.7783474922180176],
#   'premise': 'The students recognized the professor .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The scientist ) ( ( believed ( the actor ) ) . ) )',
#   'binary_parse_premise': '( ( The actor ) ( ( believed ( the scientist ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The scientist believed the actor .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN scientist)) (VP (VBD believed) (NP (DT the) (NN actor))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN actor)) (VP (VBD believed) (NP (DT the) (NN scientist))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.07289457321167,
#    -1.5044336318969727,
#    -0.8702213168144226],
#   'premise': 'The actor believed the scientist .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The tourist ) ( ( contacted ( the artist ) ) . ) )',
#   'binary_parse_premise': '( ( The artist ) ( ( contacted ( the tourist ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The tourist contacted the artist .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN tourist)) (VP (VBD contacted) (NP (DT the) (NN artist))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN artist)) (VP (VBD contacted) (NP (DT the) (NN tourist))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.469301223754883,
#    -1.4292312860488892,
#    -1.4831221103668213],
#   'premise': 'The artist contacted the tourist .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The actors ) ( ( helped ( the president ) ) . ) )',
#   'binary_parse_premise': '( ( The president ) ( ( helped ( the actors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The actors helped the president .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS actors)) (VP (VBD helped) (NP (DT the) (NN president))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN president)) (VP (VBD helped) (NP (DT the) (NNS actors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8591787815093994,
#    -1.4888015985488892,
#    -0.606814980506897],
#   'premise': 'The president helped the actors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The secretary ) ( ( introduced ( the professors ) ) . ) )',
#   'binary_parse_premise': '( ( The professors ) ( ( introduced ( the secretary ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The secretary introduced the professors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN secretary)) (VP (VBD introduced) (NP (DT the) (NNS professors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS professors)) (VP (VBD introduced) (NP (DT the) (NN secretary))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.9165282249450684,
#    -1.5400011539459229,
#    -0.6304876804351807],
#   'premise': 'The professors introduced the secretary .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The senator ) ( ( advised ( the doctors ) ) . ) )',
#   'binary_parse_premise': '( ( The doctors ) ( ( advised ( the senator ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The senator advised the doctors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN senator)) (VP (VBD advised) (NP (DT the) (NNS doctors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS doctors)) (VP (VBD advised) (NP (DT the) (NN senator))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.277885913848877,
#    -1.413446307182312,
#    -1.2405624389648438],
#   'premise': 'The doctors advised the senator .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The student ) ( ( believed ( the doctors ) ) . ) )',
#   'binary_parse_premise': '( ( The doctors ) ( ( believed ( the student ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The student believed the doctors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN student)) (VP (VBD believed) (NP (DT the) (NNS doctors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS doctors)) (VP (VBD believed) (NP (DT the) (NN student))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.628334879875183,
#    -1.2897346019744873,
#    -0.5188359618186951],
#   'premise': 'The doctors believed the student .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The student ) ( ( mentioned ( the judges ) ) . ) )',
#   'binary_parse_premise': '( ( The judges ) ( ( mentioned ( the student ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The student mentioned the judges .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN student)) (VP (VBD mentioned) (NP (DT the) (NNS judges))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS judges)) (VP (VBD mentioned) (NP (DT the) (NN student))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.4175894260406494,
#    -1.5806502103805542,
#    0.02442765235900879],
#   'premise': 'The judges mentioned the student .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The doctors ) ( ( called ( the judge ) ) . ) )',
#   'binary_parse_premise': '( ( The judge ) ( ( called ( the doctors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The doctors called the judge .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS doctors)) (VP (VBD called) (NP (DT the) (NN judge))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN judge)) (VP (VBD called) (NP (DT the) (NNS doctors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.623210906982422,
#    -1.439910650253296,
#    -1.6888258457183838],
#   'premise': 'The judge called the doctors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The president ) ( ( stopped ( the managers ) ) . ) )',
#   'binary_parse_premise': '( ( The managers ) ( ( stopped ( the president ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The president stopped the managers .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN president)) (VP (VBD stopped) (NP (DT the) (NNS managers))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS managers)) (VP (VBD stopped) (NP (DT the) (NN president))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.7713725566864014,
#    -1.602369785308838,
#    -0.37624067068099976],
#   'premise': 'The managers stopped the president .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The tourists ) ( ( introduced ( the artist ) ) . ) )',
#   'binary_parse_premise': '( ( The artist ) ( ( introduced ( the tourists ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The tourists introduced the artist .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS tourists)) (VP (VBD introduced) (NP (DT the) (NN artist))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN artist)) (VP (VBD introduced) (NP (DT the) (NNS tourists))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.1831936836242676,
#    -1.3387055397033691,
#    -1.1851403713226318],
#   'premise': 'The artist introduced the tourists .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The secretaries ) ( ( contacted ( the manager ) ) . ) )',
#   'binary_parse_premise': '( ( The manager ) ( ( contacted ( the secretaries ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The secretaries contacted the manager .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS secretaries)) (VP (VBD contacted) (NP (DT the) (NN manager))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN manager)) (VP (VBD contacted) (NP (DT the) (NNS secretaries))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.4199416637420654,
#    -1.5577725172042847,
#    -1.280313491821289],
#   'premise': 'The manager contacted the secretaries .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The secretary ) ( ( recommended ( the judges ) ) . ) )',
#   'binary_parse_premise': '( ( The judges ) ( ( recommended ( the secretary ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The secretary recommended the judges .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN secretary)) (VP (VBD recommended) (NP (DT the) (NNS judges))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS judges)) (VP (VBD recommended) (NP (DT the) (NN secretary))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.5004453659057617,
#    -1.6194697618484497,
#    -0.03415322303771973],
#   'premise': 'The judges recommended the secretary .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The professor ) ( ( called ( the actors ) ) . ) )',
#   'binary_parse_premise': '( ( The actors ) ( ( called ( the professor ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The professor called the actors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN professor)) (VP (VBD called) (NP (DT the) (NNS actors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS actors)) (VP (VBD called) (NP (DT the) (NN professor))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.782412052154541,
#    -1.3141450881958008,
#    -0.6881213784217834],
#   'premise': 'The actors called the professor .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The actors ) ( ( avoided ( the scientists ) ) . ) )',
#   'binary_parse_premise': '( ( The scientists ) ( ( avoided ( the actors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The actors avoided the scientists .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS actors)) (VP (VBD avoided) (NP (DT the) (NNS scientists))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS scientists)) (VP (VBD avoided) (NP (DT the) (NNS actors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.19521427154541,
#    -1.7047144174575806,
#    -0.7991974353790283],
#   'premise': 'The scientists avoided the actors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The artists ) ( ( encouraged ( the banker ) ) . ) )',
#   'binary_parse_premise': '( ( The banker ) ( ( encouraged ( the artists ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The artists encouraged the banker .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS artists)) (VP (VBD encouraged) (NP (DT the) (NN banker))) (. .)))',
# ...
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The doctors supported the author .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS doctors)) (VP (VBD supported) (NP (DT the) (NN author))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN author)) (VP (VBD supported) (NP (DT the) (NNS doctors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.1004786491394043,
#    -1.2882462739944458,
#    -1.1487103700637817],
#   'premise': 'The author supported the doctors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The scientists ) ( ( supported ( the secretaries ) ) . ) )',
#   'binary_parse_premise': '( ( The secretaries ) ( ( supported ( the scientists ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The scientists supported the secretaries .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS scientists)) (VP (VBD supported) (NP (DT the) (NNS secretaries))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS secretaries)) (VP (VBD supported) (NP (DT the) (NNS scientists))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.227525472640991,
#    -1.4684745073318481,
#    -1.107679009437561],
#   'premise': 'The secretaries supported the scientists .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The senators ) ( ( contacted ( the athlete ) ) . ) )',
#   'binary_parse_premise': '( ( The athlete ) ( ( contacted ( the senators ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The senators contacted the athlete .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS senators)) (VP (VBD contacted) (NP (DT the) (NN athlete))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN athlete)) (VP (VBD contacted) (NP (DT the) (NNS senators))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.59413743019104,
#    -1.4570834636688232,
#    -1.6147547960281372],
#   'premise': 'The athlete contacted the senators .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The athletes ) ( ( advised ( the authors ) ) . ) )',
#   'binary_parse_premise': '( ( The authors ) ( ( advised ( the athletes ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The athletes advised the authors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS athletes)) (VP (VBD advised) (NP (DT the) (NNS authors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS authors)) (VP (VBD advised) (NP (DT the) (NNS athletes))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.3046209812164307,
#    -1.5081881284713745,
#    -1.1571625471115112],
#   'premise': 'The authors advised the athletes .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The manager ) ( ( advised ( the banker ) ) . ) )',
#   'binary_parse_premise': '( ( The banker ) ( ( advised ( the manager ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The manager advised the banker .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN manager)) (VP (VBD advised) (NP (DT the) (NN banker))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN banker)) (VP (VBD advised) (NP (DT the) (NN manager))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.483513116836548,
#    -1.3475151062011719,
#    -1.6136751174926758],
#   'premise': 'The banker advised the manager .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The lawyers ) ( ( believed ( the doctors ) ) . ) )',
#   'binary_parse_premise': '( ( The doctors ) ( ( believed ( the lawyers ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The lawyers believed the doctors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS lawyers)) (VP (VBD believed) (NP (DT the) (NNS doctors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS doctors)) (VP (VBD believed) (NP (DT the) (NNS lawyers))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.6409759521484375,
#    -1.4177054166793823,
#    -1.7425715923309326],
#   'premise': 'The doctors believed the lawyers .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The athletes ) ( ( mentioned ( the author ) ) . ) )',
#   'binary_parse_premise': '( ( The author ) ( ( mentioned ( the athletes ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The athletes mentioned the author .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS athletes)) (VP (VBD mentioned) (NP (DT the) (NN author))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN author)) (VP (VBD mentioned) (NP (DT the) (NNS athletes))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.6680960655212402,
#    -1.417144775390625,
#    -0.44200459122657776],
#   'premise': 'The author mentioned the athletes .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The actors ) ( ( saw ( the banker ) ) . ) )',
#   'binary_parse_premise': '( ( The banker ) ( ( saw ( the actors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The actors saw the banker .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS actors)) (VP (VBD saw) (NP (DT the) (NN banker))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN banker)) (VP (VBD saw) (NP (DT the) (NNS actors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.9355640411376953,
#    -1.563085913658142,
#    -0.6119577884674072],
#   'premise': 'The banker saw the actors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The scientist ) ( ( called ( the judge ) ) . ) )',
#   'binary_parse_premise': '( ( The judge ) ( ( called ( the scientist ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The scientist called the judge .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN scientist)) (VP (VBD called) (NP (DT the) (NN judge))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN judge)) (VP (VBD called) (NP (DT the) (NN scientist))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.5223259925842285,
#    -1.4338650703430176,
#    -1.564826488494873],
#   'premise': 'The judge called the scientist .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The professors ) ( ( introduced ( the author ) ) . ) )',
#   'binary_parse_premise': '( ( The author ) ( ( introduced ( the professors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The professors introduced the author .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS professors)) (VP (VBD introduced) (NP (DT the) (NN author))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN author)) (VP (VBD introduced) (NP (DT the) (NNS professors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.181881904602051,
#    -1.496005654335022,
#    -1.0243985652923584],
#   'premise': 'The author introduced the professors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The presidents ) ( ( mentioned ( the students ) ) . ) )',
#   'binary_parse_premise': '( ( The students ) ( ( mentioned ( the presidents ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The presidents mentioned the students .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS presidents)) (VP (VBD mentioned) (NP (DT the) (NNS students))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS students)) (VP (VBD mentioned) (NP (DT the) (NNS presidents))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.331127643585205,
#    -1.6181398630142212,
#    -1.083195686340332],
#   'premise': 'The students mentioned the presidents .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The authors ) ( ( saw ( the doctor ) ) . ) )',
#   'binary_parse_premise': '( ( The doctor ) ( ( saw ( the authors ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The authors saw the doctor .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS authors)) (VP (VBD saw) (NP (DT the) (NN doctor))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN doctor)) (VP (VBD saw) (NP (DT the) (NNS authors))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.6497116088867188,
#    -1.4491617679595947,
#    -0.38155433535575867],
#   'premise': 'The doctor saw the authors .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The actor ) ( ( supported ( the professors ) ) . ) )',
#   'binary_parse_premise': '( ( The professors ) ( ( supported ( the actor ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The actor supported the professors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN actor)) (VP (VBD supported) (NP (DT the) (NNS professors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS professors)) (VP (VBD supported) (NP (DT the) (NN actor))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.2751038074493408,
#    -1.3882172107696533,
#    -0.011866569519042969],
#   'premise': 'The professors supported the actor .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The presidents ) ( ( saw ( the authors ) ) . ) )',
#   'binary_parse_premise': '( ( The authors ) ( ( saw ( the presidents ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The presidents saw the authors .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS presidents)) (VP (VBD saw) (NP (DT the) (NNS authors))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS authors)) (VP (VBD saw) (NP (DT the) (NNS presidents))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.591266632080078,
#    -1.628720760345459,
#    -1.4223241806030273],
#   'premise': 'The authors saw the presidents .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The doctor ) ( ( advised ( the scientist ) ) . ) )',
#   'binary_parse_premise': '( ( The scientist ) ( ( advised ( the doctor ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The doctor advised the scientist .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN doctor)) (VP (VBD advised) (NP (DT the) (NN scientist))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN scientist)) (VP (VBD advised) (NP (DT the) (NN doctor))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.680483341217041,
#    -1.4451913833618164,
#    -1.7730250358581543],
#   'premise': 'The scientist advised the doctor .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The student ) ( ( stopped ( the secretaries ) ) . ) )',
#   'binary_parse_premise': '( ( The secretaries ) ( ( stopped ( the student ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The student stopped the secretaries .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN student)) (VP (VBD stopped) (NP (DT the) (NNS secretaries))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS secretaries)) (VP (VBD stopped) (NP (DT the) (NN student))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.4953269958496094,
#    -1.5702213048934937,
#    -0.07292670011520386],
#   'premise': 'The secretaries stopped the student .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The lawyer ) ( ( thanked ( the doctor ) ) . ) )',
#   'binary_parse_premise': '( ( The doctor ) ( ( thanked ( the lawyer ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The lawyer thanked the doctor .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN lawyer)) (VP (VBD thanked) (NP (DT the) (NN doctor))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN doctor)) (VP (VBD thanked) (NP (DT the) (NN lawyer))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.886936664581299,
#    -1.2201061248779297,
#    -2.343991756439209],
#   'premise': 'The doctor thanked the lawyer .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The tourist ) ( ( called ( the judge ) ) . ) )',
#   'binary_parse_premise': '( ( The judge ) ( ( called ( the tourist ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The tourist called the judge .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN tourist)) (VP (VBD called) (NP (DT the) (NN judge))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN judge)) (VP (VBD called) (NP (DT the) (NN tourist))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8922340869903564,
#    -1.5988703966140747,
#    -0.5276845097541809],
#   'premise': 'The judge called the tourist .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The banker ) ( ( stopped ( the tourists ) ) . ) )',
#   'binary_parse_premise': '( ( The tourists ) ( ( stopped ( the banker ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The banker stopped the tourists .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN banker)) (VP (VBD stopped) (NP (DT the) (NNS tourists))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NNS tourists)) (VP (VBD stopped) (NP (DT the) (NN banker))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.04711651802063,
#    -1.609217643737793,
#    -0.7059295773506165],
#   'premise': 'The tourists stopped the banker .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The doctor ) ( ( encouraged ( the president ) ) . ) )',
#   'binary_parse_premise': '( ( The president ) ( ( encouraged ( the doctor ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The doctor encouraged the president .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN doctor)) (VP (VBD encouraged) (NP (DT the) (NN president))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN president)) (VP (VBD encouraged) (NP (DT the) (NN doctor))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.5791327953338623,
#    -1.3649650812149048,
#    -1.7335041761398315],
#   'premise': 'The president encouraged the doctor .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The athlete ) ( ( recommended ( the lawyer ) ) . ) )',
#   'binary_parse_premise': '( ( The lawyer ) ( ( recommended ( the athlete ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The athlete recommended the lawyer .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NN athlete)) (VP (VBD recommended) (NP (DT the) (NN lawyer))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN lawyer)) (VP (VBD recommended) (NP (DT the) (NN athlete))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [2.045957088470459,
#    -1.4673004150390625,
#    -0.8751988410949707],
#   'premise': 'The lawyer recommended the athlete .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  {'binary_parse_hypothesis': '( ( The tourists ) ( ( introduced ( the manager ) ) . ) )',
#   'binary_parse_premise': '( ( The manager ) ( ( introduced ( the tourists ) ) . ) )',
#   'heuristic': 'lexical_overlap',
#   'hypothesis': 'The tourists introduced the manager .',
#   'label': 1,
#   'parse_hypothesis': '(ROOT (S (NP (DT The) (NNS tourists)) (VP (VBD introduced) (NP (DT the) (NN manager))) (. .)))',
#   'parse_premise': '(ROOT (S (NP (DT The) (NN manager)) (VP (VBD introduced) (NP (DT the) (NNS tourists))) (. .)))',
#   'predicted_label': 0,
#   'predicted_scores': [1.8661723136901855,
#    -1.4181361198425293,
#    -0.6841092109680176],
#   'premise': 'The manager introduced the tourists .',
#   'subcase': 'ln_subject/object_swap',
#   'template': 'temp1'},
#  ...]

# %%
temp_dict = {}
for ex in mis_classified_types_dict[(1, 0)]:
  key = ex['heuristic']
  if key not in temp_dict:
    temp_dict[key] = 0
  temp_dict[key] += 1

temp_dict
# Out:
# {'constituent': 4994, 'lexical_overlap': 4937, 'subsequence': 5000}

# %%
temp_dict = {}
for ex in correct_classified_exs:
  if ex['label'] != 1:
    continue
  key = ex['heuristic']
  if key not in temp_dict:
    temp_dict[key] = 0
  temp_dict[key] += 1

temp_dict
# Out:
# {}
